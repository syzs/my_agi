# %% [markdown]
# #### 特征工程
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 常用特征
# ###### 行为数据
# ![image-2.png](attachment:image-2.png)
#
# ###### 用户关系数据
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ###### 属性、标签类数据
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ###### 内容类数据
#
# ![image-7.png](attachment:image-7.png)
# ![image-6.png](attachment:image-6.png)
#
#
# ###### 场景信息（上下文信息）
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ##### one-hot/multi-hot
# ##### 归一化、分桶
# https://time.geekbang.org/column/article/295300?utm_campaign=geektime_search&utm_content=geektime_search&utm_medium=geektime_search&utm_source=geektime_search&utm_term=geektime_search

# %% [markdown]
# ![image.png](attachment:image.png)
